# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('pop_profit.txt')

# %%
data
# Out:
#     population    profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
x = data.iloc[:,:-1] #:,:-1 determines the selection of all rows and columns except last one
y = data.iloc[:,-1] #:,-1 detemines selection of all rows and last colums
x,y
# Out:
# (    population
#  0       6.1101
#  1       5.5277
#  2       8.5186
#  3       7.0032
#  4       5.8598
#  ..         ...
#  92      5.8707
#  93      5.3054
#  94      8.2934
#  95     13.3940
#  96      5.4369
#
#  [97 rows x 1 columns],
#  0     17.59200
#  1      9.13020
#  2     13.66200
#  3     11.85400
#  4      6.82330
#          ...
#  92     7.20290
#  93     1.98690
#  94     0.14454
#  95     9.05510
#  96     0.61705
#  Name:  profit, Length: 97, dtype: float64)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
y_pred = model.predict(x)
print(x.head())
y_pred
# Out:
#    population
# 0      6.1101
# 1      5.5277
# 2      8.5186
# 3      7.0032
# 4      5.8598
# array([ 3.39377399,  2.6989512 ,  6.26719552,  4.45927234,  3.09515767,
#         6.10530086,  5.02381586,  6.33818102,  3.84247394,  2.13452698,
#         2.91727635, 13.00234766,  2.94507404,  6.13572322,  2.833764  ,
#         2.52202431,  3.69835548,  2.22460102,  3.77494824,  4.53992141,
#         3.48802365, 20.28701109,  2.65409313,  3.65146926,  2.74333205,
#        18.70624151, 11.40845471,  9.17628876, 11.82363042, 22.59314512,
#         2.37050903,  3.96559502,  7.13763287,  3.13333475,  5.90033768,
#         5.56903223,  5.7629002 ,  2.79272364, 11.41799898,  3.68403908,
#         2.55483273,  4.31527318, 10.07225703,  2.99243747,  5.43934948,
#         4.56652606,  2.1531383 ,  3.02548451, 10.06271276,  2.71553436,
#         5.09993141,  2.43648379,  4.96118159,  5.17497322,  3.65946258,
#         3.69060076,  3.58955081,  2.83257096,  7.21160096,  7.38268198,
# ...

# %%
plt.scatter(x,y)
plt.plot(x,y_pred,color='red')

# %% [markdown]
# # salary and years of experince

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
data = pd.read_csv('Salary_Data.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values
x,y
# Out:
# (array([[ 1.1],
#         [ 1.3],
#         [ 1.5],
#         [ 2. ],
#         [ 2.2],
#         [ 2.9],
#         [ 3. ],
#         [ 3.2],
#         [ 3.2],
#         [ 3.7],
#         [ 3.9],
#         [ 4. ],
#         [ 4. ],
#         [ 4.1],
#         [ 4.5],
#         [ 4.9],
#         [ 5.1],
#         [ 5.3],
#         [ 5.9],
#         [ 6. ],
#         [ 6.8],
#         [ 7.1],
#         [ 7.9],
#         [ 8.2],
#         [ 8.7],
#         [ 9. ],
#         [ 9.5],
#         [ 9.6],
#         [10.3],
#         [10.5]]),
#  array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#          54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#          61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#          98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#         122391., 121872.]))

# %%
plt.scatter(x,y)

# %%
x_test,x_train,y_test,y_train = train_test_split(x,y,test_size = 0.3, random_state=0)

# %%
print(f'x_train : {x_train}')
print(f'x_test : {x_test}')
print(f'y_train : {y_train}')
print(f'y_test : {y_test}')
# Out:
# x_train : [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]]
# x_test : [[ 7.9]
#  [ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]
# y_train : [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.]
# y_test : [101302.  56642.  66029.  64445.  61111. 113812.  91738.  46205. 121872.
#   60150.  39891.  81363.  93940.  57189.  54445. 105582.  43525.  39343.
#   98273.  67938.  56957.]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
print(y_train)
print(y_pred)
# Out:
# [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.]
# [ 99720.58826844  50725.06206563  72283.09359487  53664.7936378
#   66403.63045053 102660.31984061  88941.57250382  35046.49368074
#  125198.2618939   51704.97258969  43865.68839724  80122.37778732
#   81102.28831137  58564.34625808  53664.7936378  110499.60403306
#   41905.86734913  33086.67263262  91881.30407599  70323.27254676
#   61504.07783025]

# %%
plt.scatter(x_train,y_train,color='red')
plt.scatter(x_test,y_test,color='blue')
plt.plot(x_train,model.predict(x_train),color='green')
plt.show()
