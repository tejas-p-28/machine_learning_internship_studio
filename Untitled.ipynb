# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5]
b = [2,4,5,1,7]
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5]
b = [2,4,5,1,7]
plt.scatter(a,b, s= 20, color='black')
plt.show()

# %%
# x = [23,4,45,10,12,16,17,11,25]
import numpy as np
data = [np.random.normal(0,100,10)]
print(data)
plt.hist(data,bins=9,color='blue',alpha = 0.1)
plt.show
# Out:
# [array([ 146.10117682,  -94.00585083, -178.65138222,   -8.54138808,
#        -133.26131681,  -68.78685748,  -29.94349095,  -63.47427582,
#          15.26874039,  -82.62711401])]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# data = [np.random.normal(0,100,10)]
x = ([23,4,45,10,12,16,17,11,25],[23,45,23,532,432],[23,4,45,10,12,16,17,11,25])
print(x)
plt.boxplot(x,patch_artist=True)
plt.show
# Out:
# ([23, 4, 45, 10, 12, 16, 17, 11, 25], [23, 45, 23, 532, 432], [23, 4, 45, 10, 12, 16, 17, 11, 25])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# import pandas as pd
# data = pd.read_excel('netflix_titles.xlsx',usecols=['duration'])
# data.sample(5)
# plt.pie(data,labels = imputer.Transform(data),colors='red,green',startangle=90,shadow=True)
