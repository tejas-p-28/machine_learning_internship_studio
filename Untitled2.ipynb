# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('IMDb Top TV Series.csv')
df.head
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            900 non-null    object
#  1   Year             888 non-null    object
#  2   Parental Rating  888 non-null    object
#  3   Rating           900 non-null    float64
#  4   Number of Votes  900 non-null    object
#  5   Description      900 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 42.3+ KB
#            Rating
# count  900.000000
# mean     7.862333
# std      0.817776
# min      1.600000
# 25%      7.500000
# 50%      8.000000
# 75%      8.400000
# max      9.500000

# %%
x = df[:,:-1]
y = df [:,-1]
x,y
# Out:
# (array([['1. Game of Thrones', '2011–2019', 'TV-MA', 9.2, '2.3M'],
#         ['2. Breaking Bad', '2008–2013', 'TV-MA', 9.5, '2.1M'],
#         ['3. Stranger Things', '2016–2025', 'TV-14', 8.7, '1.3M'],
#         ...,
#         ['898. How I Met Your Father', '2022–2023', 'TV-14', 5.7, '26K'],
#         ['899. Delhi Crime', '2019–', 'TV-MA', 8.5, '26K'],
#         ['900. Caprica', '2009–2010', 'TV-14', 7.1, '26K']], dtype=object),
#  array(['Nine noble families fight for control over the lands of Westeros, while an ancient enemy returns after being dormant for millennia.',
#         "A chemistry teacher diagnosed with inoperable lung cancer turns to manufacturing and selling methamphetamine with a former student in order to secure his family's future.",
#         'When a young boy vanishes, a small town uncovers a mystery involving secret experiments, terrifying supernatural forces and one strange little girl.',
# ...

# %%
plt.scatter(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.scatter(x,y)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3798 @_copy_docstring_and_deprecators(Axes.scatter)
#    3799 def scatter(
#    3800     x: float | ArrayLike,
#    (...)
#    3815     **kwargs,
#    3816 ) -> PathCollection:
# -> 3817     __ret = gca().scatter(
#    3818         x,
#    3819         y,
#    3820         s=s,
#    3821         c=c,
#    3822         marker=marker,
#    3823         cmap=cmap,
#    3824         norm=norm,
#    3825         vmin=vmin,
#    3826         vmax=vmax,
#    3827         alpha=alpha,
#    3828         linewidths=linewidths,
#    3829         edgecolors=edgecolors,
# ...
