# %%
import numpy as np
import pandas as pd
data = pd.read_excel("netflix_titles.xlsx")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
data.tail()
# Out:
#      show_id     type                    title  \
# 2551   s2552  TV Show               Dead to Me
# 2552   s2553  TV Show  Restaurants on the Edge
# 2553   s2554  TV Show                 The Eddy
# 2554   s2555  TV Show               The Hollow
# 2555   s2556    Movie                  Aerials
#
#                                                director  \
# 2551                                                NaN
# 2552                                                NaN
# 2553  Damien Chazelle, Houda Benyamina, Laïla Marrak...
# 2554                                                NaN
# 2555                                         S.A. Zaidi
#
#                                                    cast  \
# 2551  Christina Applegate, Linda Cardellini, James M...
# 2552         Nick Liberato, Karin Bohn, Dennis Prescott
# 2553  André Holland, Joanna Kulig, Amandla Stenberg,...
# 2554  Adrian Petriw, Ashleigh Ball, Connor Parnall, ...
# ...

# %%
data.sort_values(by = "show_id")
# Out:
#      show_id     type                                  title  \
# 0         s1    Movie                   Dick Johnson Is Dead
# 9        s10    Movie                           The Starling
# 99      s100  TV Show                           On the Verge
# 999    s1000    Movie                               Stowaway
# 1000   s1001    Movie                               Wild Dog
# ...      ...      ...                                    ...
# 994     s995    Movie                  This Lady Called Life
# 995     s996    Movie                              Vizontele
# 996     s997    Movie                             HOMUNCULUS
# 997     s998  TV Show  Life in Color with David Attenborough
# 998     s999    Movie                   Searching For Sheela
#
#                               director  \
# 0                      Kirsten Johnson
# 9                       Theodore Melfi
# 99                                 NaN
# 999                          Joe Penna
# ...

# %%
#display column of the file
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#data type of the file
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
#shows the shape of data
data.shape
# Out:
# (2556, 12)

# %%
#shows whole data 
data.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                    title  \
# 0         s1    Movie     Dick Johnson Is Dead
# 1         s2  TV Show            Blood & Water
# 2         s3  TV Show                Ganglands
# 3         s4  TV Show    Jailbirds New Orleans
# 4         s5  TV Show             Kota Factory
# ...      ...      ...                      ...
# 2551   s2552  TV Show               Dead to Me
# 2552   s2553  TV Show  Restaurants on the Edge
# 2553   s2554  TV Show                 The Eddy
# 2554   s2555  TV Show               The Hollow
# 2555   s2556    Movie                  Aerials
#
#                                                director  \
# 0                                       Kirsten Johnson
# 1                                                   NaN
# 2                                       Julien Leclercq
# 3                                                   NaN
# 4                                                   NaN
# ...

# %%
data.value_counts()
# Out:
# show_id  type     title                         director             cast                                                                                                                                                                                    country                             date_added  release_year  rating  duration  listed_in                                           description
# s10      Movie    The Starling                  Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor                  United States                       2021-09-24  2021          PG-13   104 min   Comedies, Dramas                                    A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.    1
# ...

# %%
data.sample(5)
# Out:
#      show_id     type         title        director  \
# 2402   s2403    Movie   From A to B  Ali F. Mostafa
# 1459   s1460    Movie  Mean Girls 2  Melanie Mayron
# 1308   s1309  TV Show         Booba             NaN
# 2168   s2169  TV Show   Mystery Lab             NaN
# 785     s786  TV Show     Cocomelon             NaN
#
#                                                    cast  \
# 2402  Fahad Albutairi, Shadi Alfons, Fadi Rifaai, Sa...
# 1459  Meaghan Martin, Maiara Walsh, Jennifer Stone, ...
# 1308                                        Roman Karev
# 2168  Felipe Castanhari, Lilian Regina, Bruno Mirand...
# 785                                                 NaN
#
#                                                 country date_added  \
# 2402  United Arab Emirates, Jordan, Lebanon, Saudi A... 2020-06-11
# 1459                                      United States 2021-01-01
# 1308                                     United Kingdom 2021-02-15
# ...

# %%
pd.read_excel('netflix_titles.xlsx', usecols=['director','show_id','title']).sample(5)
# Out:
#      show_id                           title        director
# 417     s418  Chhota Bheem in African Safari     Binayak Das
# 1267   s1268                        Who Am I   Baran bo Odar
# 2548   s2549                  Trial By Media             NaN
# 1032   s1033                    Love Naggers             NaN
# 2103   s2104                    Class of '83  Atul Sabharwal

# %%
pd.groupby('realease_year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 pd.groupby('realease_year')
#
# AttributeError: module 'pandas' has no attribute 'groupby'
